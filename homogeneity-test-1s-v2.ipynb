# %%
import pandas as pd
import numpy as np
from __future__ import division
import calendar
import time
import datetime
from datetime import date, timedelta
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats
colorz=sns.color_palette("husl", 8)
sns.palplot(sns.color_palette("husl", 8))

# %%
file1=pd.read_table('/Users/stella/Desktop/Exported 1s data before 215PM (0.3-17um ONLY).txt')
file2=pd.read_table('/Users/stella/Desktop/Exported 1s data after 215PM  (0.3-17um ONLY).txt')

# %%
df1=file1.copy(False)
df2=file2.copy(False)

# %%
del df1['relative time [s]']
del df2['relative time [s]']

# %%
df1['time']=pd.to_datetime(df1['time'], format = "%I:%M:%S %p").apply(lambda x: x.time())
df2['time']=pd.to_datetime(df2['time'], format = "%I:%M:%S %p").apply(lambda x: x.time())

# %%
#df3=df2.join(df1)

# %% [raw]
# # particle count multiplied by 10 to compensate for dilution
# df1['Cn [P/cm^3]']=df1['Cn [P/cm^3]']/10
# df2['Cn [P/cm^3]']=df2['Cn [P/cm^3]']*10

# %%
# time range for each test
r0_1=datetime.time(12,27,45); r0_2=datetime.time(12,37,45)
r1_1=datetime.time(12,38,45); r1_2=datetime.time(12,48,45)
r2_1=datetime.time(12,52,30); r2_2=datetime.time(13,2,30)
r3_1=datetime.time(13,6,30); r3_2=datetime.time(13,16,30)
r4_1=datetime.time(13,21); r4_2=datetime.time(13,31)
r5_1=datetime.time(13,34); r5_2=datetime.time(13,44)
r6_1=datetime.time(13,49); r6_2=datetime.time(13,59)
r7_1=datetime.time(14,4); r7_2=datetime.time(14,14)
r8_1=datetime.time(14,17); r8_2=datetime.time(14,27)
r9_1=datetime.time(14,30); r9_2=datetime.time(14,40)
r10_1=datetime.time(14,44); r10_2=datetime.time(14,54)
r11_1=datetime.time(14,57); r11_2=datetime.time(15,7)
r12_1=datetime.time(15,10); r12_2=datetime.time(15,20)
r13_1=datetime.time(15,23); r13_2=datetime.time(15,33)

# %%
df1=df1.set_index('time')
df2=df2.set_index('time')

# %%
# slice dataframe by time ranges
test0=df1.ix[r0_1:r0_2].reset_index()
test1=df1.ix[r1_1:r1_2].reset_index()
test2=df1.ix[r2_1:r2_2].reset_index()
test3=df1.ix[r3_1:r3_2].reset_index()
test4=df1.ix[r4_1:r4_2].reset_index()
test5=df1.ix[r5_1:r5_2].reset_index()
test6=df1.ix[r6_1:r6_2].reset_index()
test7=df1.ix[r7_1:r7_2].reset_index()
test8=df2.ix[r8_1:r8_2].reset_index()
test9=df2.ix[r9_1:r9_2].reset_index()
test10=df2.ix[r10_1:r10_2].reset_index()
test11=df2.ix[r11_1:r11_2].reset_index()
test12=df2.ix[r12_1:r12_2].reset_index()
test13=df2.ix[r13_1:r13_2].reset_index()

# %%
print('sample size:')
print(test1.shape[0])
print(test2.shape[0])
print(test3.shape[0])
print(test4.shape[0])
print(test5.shape[0])
print(test6.shape[0])
print(test7.shape[0])
print(test8.shape[0])
print(test9.shape[0])
print(test10.shape[0])
print(test11.shape[0])
print(test12.shape[0])
print(test13.shape[0])
# Out:
# sample size:
# 600
# 601
# 600
# 601
# 601
# 600
# 601
# 601
# 601
# 601
# 601
# 601
# 600

# %% [raw]
# format = "%I:%M:%S %p"
# datetime.datetime.strptime(r12_1,format).time()

# %%
mean0=test0['Cn [P/cm^3]'].mean()
mean1=test1['Cn [P/cm^3]'].mean()
mean2=test2['Cn [P/cm^3]'].mean()
mean3=test3['Cn [P/cm^3]'].mean()
mean4=test4['Cn [P/cm^3]'].mean()
mean5=test5['Cn [P/cm^3]'].mean()
mean6=test6['Cn [P/cm^3]'].mean()
mean7=test7['Cn [P/cm^3]'].mean()
mean8=test8['Cn [P/cm^3]'].mean()
mean9=test9['Cn [P/cm^3]'].mean()
mean10=test10['Cn [P/cm^3]'].mean()
mean11=test11['Cn [P/cm^3]'].mean()
mean12=test12['Cn [P/cm^3]'].mean()
mean13=test13['Cn [P/cm^3]'].mean()

# %%
meanlist=[mean0,mean1,mean2,mean3,mean4,mean5,mean6,mean7,mean8,mean9,mean10,mean11,mean12,mean13]

# %%
round(max(meanlist)), round(min(meanlist))
# Out:
# (38481, 19513)

# %%
np.mean(meanlist)
# Out:
# 24919.995019265723

# %%
sd0=np.round(np.std(test0['Cn [P/cm^3]']))
sd1=np.round(np.std(test1['Cn [P/cm^3]']))
sd2=np.round(np.std(test2['Cn [P/cm^3]']))
sd3=np.round(np.std(test3['Cn [P/cm^3]']))
sd4=np.round(np.std(test4['Cn [P/cm^3]']))
sd5=np.round(np.std(test5['Cn [P/cm^3]']))
sd6=np.round(np.std(test6['Cn [P/cm^3]']))
sd7=np.round(np.std(test7['Cn [P/cm^3]']))
sd8=np.round(np.std(test8['Cn [P/cm^3]']))
sd9=np.round(np.std(test9['Cn [P/cm^3]']))
sd10=np.round(np.std(test10['Cn [P/cm^3]']))
sd11=np.round(np.std(test11['Cn [P/cm^3]']))
sd12=np.round(np.std(test12['Cn [P/cm^3]']))
sd13=np.round(np.std(test13['Cn [P/cm^3]']))

# %%
sdlist=[sd0,sd1,sd2,sd3,sd4,sd5,sd6,sd7,sd8,sd9,sd10,sd11,sd12,sd13]

# %%
np.mean(sdlist)
# Out:
# 3415.5

# %%
max(sdlist), min(sdlist)
# Out:
# (5055.823714113687, 2816.609810871383)

# %%
plt.plot(test1['time'],test1['Cn [P/cm^3]'])

# %%
ind = np.arange(len(meanlist))
width = .5
colours=[colorz[5],colorz[5],colorz[5],colorz[5],
         colorz[7],colorz[7],colorz[7],colorz[0],
         colorz[1],colorz[2],colorz[3],colorz[5],colorz[2],colorz[2]]
plt.figure(figsize=(10,7))
plt.title('Averages',fontsize=14)

plt.xlim([-0.5,13.5])
#pyplot.ylabel('Age (years)')
plt.xticks(ind,('1','5','9','1','1','5','9','9','9','9','9','9','5','1'))
plt.xlabel('Port',fontsize=12)
plt.ylabel('Cn (P/cm$^3$)',fontsize=12)

plt.bar(ind[4],meanlist[4],width,color=colours[4],align='center',yerr=sdlist[4],ecolor='k',alpha=0.8)
plt.bar(ind[7],meanlist[7],width,color=colours[7],align='center',yerr=sdlist[7],ecolor='k',alpha=0.8)
plt.bar(ind[8],meanlist[8],width,color=colours[8],align='center',yerr=sdlist[8],ecolor='k',alpha=0.8)
plt.bar(ind[9],meanlist[9],width,color=colours[9],align='center',yerr=sdlist[9],ecolor='k',alpha=0.8)
plt.bar(ind[10],meanlist[10],width,color=colours[10],align='center',yerr=sdlist[10],ecolor='k',alpha=0.8)
plt.bar(ind[11],meanlist[11],width,color=colours[11],align='center',yerr=sdlist[11],ecolor='k',alpha=0.8)
plt.bar(ind[0],meanlist[0],width,color=colours[0],align='center',yerr=sdlist[0],ecolor='k',alpha=0.8)

labels = ['Tier 1', 'Tier 2','Tier 3','Tier 4','Tier 5', 'Tier 6']
plt.legend(labels,loc='best')

plt.bar(ind[1],meanlist[1],width,color=colours[1],align='center',yerr=sdlist[1],ecolor='k',alpha=0.8)
plt.bar(ind[2],meanlist[2],width,color=colours[2],align='center',yerr=sdlist[2],ecolor='k',alpha=0.8)
plt.bar(ind[3],meanlist[3],width,color=colours[3],align='center',yerr=sdlist[3],ecolor='k',alpha=0.8)
plt.bar(ind[5],meanlist[5],width,color=colours[5],align='center',yerr=sdlist[5],ecolor='k',alpha=0.8)
plt.bar(ind[6],meanlist[6],width,color=colours[6],align='center',yerr=sdlist[6],ecolor='k',alpha=0.8)
plt.bar(ind[12],meanlist[12],width,color=colours[12],align='center',yerr=sdlist[12],ecolor='k',alpha=0.8)
plt.bar(ind[13],meanlist[13],width,color=colours[13],align='center',yerr=sdlist[13],ecolor='k',alpha=0.8)
plt.plot([-0.25, 13.25], [24920, 24920], '--')
plt.plot([3.75, 13.25], [22542, 22542], '--')

plt.annotate('mean = 22542', xy=(2, 1), xytext=(13.55, 22242),color='g')
plt.annotate('mean = 24920', xy=(2, 1), xytext=(13.55, 24620),color='royalblue')

plt.savefig('/Users/stella/Desktop/mean.pdf')

# %%
sns.palplot(sns.color_palette("husl", 8))

# %%
mean0=test0['X50(V) [micro-m]'].mean()
mean1=test1['X50(V) [micro-m]'].mean()
mean2=test2['X50(V) [micro-m]'].mean()
mean3=test3['X50(V) [micro-m]'].mean()
mean4=test4['X50(V) [micro-m]'].mean()
mean5=test5['X50(V) [micro-m]'].mean()
mean6=test6['X50(V) [micro-m]'].mean()
mean7=test7['X50(V) [micro-m]'].mean()
mean8=test8['X50(V) [micro-m]'].mean()
mean9=test9['X50(V) [micro-m]'].mean()
mean10=test10['X50(V) [micro-m]'].mean()
mean11=test11['X50(V) [micro-m]'].mean()
mean12=test12['X50(V) [micro-m]'].mean()
mean13=test13['X50(V) [micro-m]'].mean()

# %%
meanlist=[mean0,mean1,mean2,mean3,mean4,mean5,mean6,mean7,mean8,mean9,mean10,mean11,mean12,mean13]

# %%
meanlist
# Out:
# [1.20483402828619,
#  0.9827486116666665,
#  1.1970118236272878,
#  1.2303436299999997,
#  1.1242634475873543,
#  0.9827621980033274,
#  1.0212146233333332,
#  1.12653149750416,
#  1.1074302595673886,
#  1.1545055540765392,
#  1.0394928219633954,
#  1.0575048202995017,
#  1.0358677054908496,
#  1.0150032083333325]

# %%
sd0=np.std(test0['X50(V) [micro-m]'])
sd1=np.std(test1['X50(V) [micro-m]'])
sd2=np.std(test2['X50(V) [micro-m]'])
sd3=np.std(test3['X50(V) [micro-m]'])
sd4=np.std(test4['X50(V) [micro-m]'])
sd5=np.std(test5['X50(V) [micro-m]'])
sd6=np.std(test6['X50(V) [micro-m]'])
sd7=np.std(test7['X50(V) [micro-m]'])
sd8=np.std(test8['X50(V) [micro-m]'])
sd9=np.std(test9['X50(V) [micro-m]'])
sd10=np.std(test10['X50(V) [micro-m]'])
sd11=np.std(test11['X50(V) [micro-m]'])
sd12=np.std(test12['X50(V) [micro-m]'])
sd13=np.std(test13['X50(V) [micro-m]'])

# %%
sdlist=[sd0,sd1,sd2,sd3,sd4,sd5,sd6,sd7,sd8,sd9,sd10,sd11,sd12,sd13]

# %%
sdlist
# Out:
# [0.433537274419151,
#  0.4805379416733094,
#  0.48812755684118,
#  0.37794709656477465,
#  0.42355309620304477,
#  0.4218031111381067,
#  0.4356338632998374,
#  0.46425781922876125,
#  0.47660486959557197,
#  0.4388589714146056,
#  0.5051360260023441,
#  0.46973941173283074,
#  0.45546512956750623,
#  0.4782362262869522]
